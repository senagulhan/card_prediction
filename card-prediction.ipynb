# %% [markdown]
# <a href="https://www.kaggle.com/code/nursenaglhan/card-prediction?scriptVersionId=205148039" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("//kaggle//input//default-of-credit-card-clients-dataset//UCI_Credit_Card.csv")
df.info()
df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
df=df.drop("ID",axis=1)
df.info()
df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   30000 non-null  float64
#  1   SEX                         30000 non-null  int64
#  2   EDUCATION                   30000 non-null  int64
#  3   MARRIAGE                    30000 non-null  int64
#  4   AGE                         30000 non-null  int64
#  5   PAY_0                       30000 non-null  int64
#  6   PAY_2                       30000 non-null  int64
#  7   PAY_3                       30000 non-null  int64
#  8   PAY_4                       30000 non-null  int64
#  9   PAY_5                       30000 non-null  int64
#  10  PAY_6                       30000 non-null  int64
#  11  BILL_AMT1                   30000 non-null  float64
#  12  BILL_AMT2                   30000 non-null  float64
# ...

# %%
y=df["default.payment.next.month"]
x=df.drop("default.payment.next.month",axis=1)
print(df.shape)
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=16)
log = LogisticRegression(max_iter=1000)
model=log.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# (30000, 24)
# 0.7773333333333333

# %%
columns=x.columns.tolist()

for col in columns:
    plt.style.use("fivethirtyeight")
    plt.figure(figsize=(14,14))
    plt.scatter(x[col],y)
    plt.xlabel(col,fontsize=14)
    plt.ylabel("default.payment.next.month",fontsize=14)
    plt.show()
